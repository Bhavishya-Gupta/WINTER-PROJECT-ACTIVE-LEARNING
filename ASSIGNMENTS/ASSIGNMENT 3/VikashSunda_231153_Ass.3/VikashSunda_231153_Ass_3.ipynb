# %% [markdown]
# # Assignment 3

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets,transforms

import numpy as np
import pandas as pd
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt

# %% [markdown]
# #### CNN MODEL

# %%
class ConvolutionalNeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 10, 3, 1)
        self.conv2 = nn.Conv2d(10, 25, 3, 1)
        self.fc1 = nn.Linear(25*6*6, 120)
        self.fc2 = nn.Linear(120, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(F.max_pool2d(x, 2, 2))
        x = F.relu(F.max_pool2d(x, 2, 2))
        x = x.view(-1, 25*6*6)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

    def extract_features(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.max_pool2d(x, 2, 2)
        x = x.view(x.size(0), -1)
        return x

model = ConvolutionalNeuralNetwork()
model
# Out:
# ConvolutionalNeuralNetwork(
#   (conv1): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 25, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=900, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=10, bias=True)
# )

# %%
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.01)
transform = transforms.ToTensor()

train_data = datasets.MNIST(root = 'cnn_data', train = True, download = True, transform = transform)
test_data = datasets.MNIST(root = 'cnn_data', train = False, download = True, transform = transform)

train_loader = DataLoader(train_data, batch_size = 10, shuffle = True)
test_loader = DataLoader(test_data, batch_size = 10, shuffle = False)

# %% [markdown]
# #### Training and testing

# %%
test_correct = 0

for epoch in range(10):
    total_loss = 0
    for i, (X_train, y_train) in enumerate(train_loader):
        y_prediction = model(X_train)
        loss = loss_function(y_prediction, y_train)
        total_loss += loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f'epoch: {epoch + 1}     loss: {total_loss / len(train_loader) :.5f}')

with torch.no_grad():
    for i, (X_test, y_test) in enumerate(test_loader):
        y_value = model(X_test)
        loss = loss_function(y_value, y_test)

        test_correct += (torch.max(y_value, 1)[1] == y_test).sum()
        print(f'Accuracy for Custom CNN: {test_correct/len(test_data)*100 :.2f}%')
# Out:
# epoch: 1     loss: 2.30338
# epoch: 2     loss: 2.30357
# epoch: 3     loss: 2.30377
# epoch: 4     loss: 2.30348
# epoch: 5     loss: 2.30346
# epoch: 6     loss: 2.30387
# epoch: 7     loss: 2.30336
# epoch: 8     loss: 2.30374
# epoch: 9     loss: 2.30372
# epoch: 10     loss: 2.30352
# Accuracy for Custom CNN: 0.02%
# Accuracy for Custom CNN: 0.03%
# Accuracy for Custom CNN: 0.04%
# Accuracy for Custom CNN: 0.07%
# Accuracy for Custom CNN: 0.09%
# Accuracy for Custom CNN: 0.10%
# Accuracy for Custom CNN: 0.10%
# Accuracy for Custom CNN: 0.11%
# Accuracy for Custom CNN: 0.12%
# Accuracy for Custom CNN: 0.14%
# Accuracy for Custom CNN: 0.15%
# Accuracy for Custom CNN: 0.15%
# Accuracy for Custom CNN: 0.15%
# Accuracy for Custom CNN: 0.17%
# Accuracy for Custom CNN: 0.19%
# Accuracy for Custom CNN: 0.20%
# Accuracy for Custom CNN: 0.21%
# Accuracy for Custom CNN: 0.23%
# Accuracy for Custom CNN: 0.25%
# Accuracy for Custom CNN: 0.28%
# Accuracy for Custom CNN: 0.31%
# Accuracy for Custom CNN: 0.31%
# Accuracy for Custom CNN: 0.33%
# Accuracy for Custom CNN: 0.34%
# Accuracy for Custom CNN: 0.34%
# Accuracy for Custom CNN: 0.35%
# Accuracy for Custom CNN: 0.37%
# Accuracy for Custom CNN: 0.40%
# Accuracy for Custom CNN: 0.41%
# Accuracy for Custom CNN: 0.41%
# Accuracy for Custom CNN: 0.42%
# Accuracy for Custom CNN: 0.43%
# Accuracy for Custom CNN: 0.44%
# Accuracy for Custom CNN: 0.46%
# Accuracy for Custom CNN: 0.49%
# Accuracy for Custom CNN: 0.52%
# Accuracy for Custom CNN: 0.52%
# Accuracy for Custom CNN: 0.54%
# Accuracy for Custom CNN: 0.56%
# Accuracy for Custom CNN: 0.57%
# Accuracy for Custom CNN: 0.58%
# Accuracy for Custom CNN: 0.60%
# Accuracy for Custom CNN: 0.61%
# Accuracy for Custom CNN: 0.62%
# Accuracy for Custom CNN: 0.62%
# Accuracy for Custom CNN: 0.63%
# Accuracy for Custom CNN: 0.63%
# Accuracy for Custom CNN: 0.65%
# Accuracy for Custom CNN: 0.67%
# Accuracy for Custom CNN: 0.67%
# Accuracy for Custom CNN: 0.69%
# Accuracy for Custom CNN: 0.69%
# Accuracy for Custom CNN: 0.71%
# Accuracy for Custom CNN: 0.72%
# Accuracy for Custom CNN: 0.72%
# Accuracy for Custom CNN: 0.72%
# Accuracy for Custom CNN: 0.72%
# Accuracy for Custom CNN: 0.72%
# Accuracy for Custom CNN: 0.73%
# Accuracy for Custom CNN: 0.73%
# Accuracy for Custom CNN: 0.73%
# Accuracy for Custom CNN: 0.75%
# Accuracy for Custom CNN: 0.75%
# Accuracy for Custom CNN: 0.75%
# Accuracy for Custom CNN: 0.77%
# Accuracy for Custom CNN: 0.78%
# Accuracy for Custom CNN: 0.79%
# Accuracy for Custom CNN: 0.81%
# Accuracy for Custom CNN: 0.82%
# Accuracy for Custom CNN: 0.84%
# Accuracy for Custom CNN: 0.85%
# Accuracy for Custom CNN: 0.86%
# Accuracy for Custom CNN: 0.87%
# Accuracy for Custom CNN: 0.88%
# Accuracy for Custom CNN: 0.90%
# Accuracy for Custom CNN: 0.92%
# Accuracy for Custom CNN: 0.94%
# Accuracy for Custom CNN: 0.96%
# Accuracy for Custom CNN: 0.97%
# Accuracy for Custom CNN: 0.99%
# Accuracy for Custom CNN: 1.00%
# Accuracy for Custom CNN: 1.01%
# Accuracy for Custom CNN: 1.03%
# Accuracy for Custom CNN: 1.06%
# Accuracy for Custom CNN: 1.08%
# Accuracy for Custom CNN: 1.09%
# Accuracy for Custom CNN: 1.09%
# Accuracy for Custom CNN: 1.09%
# Accuracy for Custom CNN: 1.10%
# Accuracy for Custom CNN: 1.10%
# Accuracy for Custom CNN: 1.12%
# Accuracy for Custom CNN: 1.13%
# Accuracy for Custom CNN: 1.15%
# Accuracy for Custom CNN: 1.15%
# Accuracy for Custom CNN: 1.17%
# Accuracy for Custom CNN: 1.18%
# Accuracy for Custom CNN: 1.21%
# Accuracy for Custom CNN: 1.23%
# Accuracy for Custom CNN: 1.25%
# Accuracy for Custom CNN: 1.26%
# Accuracy for Custom CNN: 1.28%
# Accuracy for Custom CNN: 1.30%
# Accuracy for Custom CNN: 1.32%
# Accuracy for Custom CNN: 1.35%
# Accuracy for Custom CNN: 1.36%
# Accuracy for Custom CNN: 1.37%
# Accuracy for Custom CNN: 1.37%
# Accuracy for Custom CNN: 1.38%
# Accuracy for Custom CNN: 1.39%
# Accuracy for Custom CNN: 1.40%
# Accuracy for Custom CNN: 1.40%
# Accuracy for Custom CNN: 1.40%
# Accuracy for Custom CNN: 1.41%
# Accuracy for Custom CNN: 1.44%
# Accuracy for Custom CNN: 1.44%
# Accuracy for Custom CNN: 1.44%
# Accuracy for Custom CNN: 1.44%
# Accuracy for Custom CNN: 1.45%
# Accuracy for Custom CNN: 1.47%
# Accuracy for Custom CNN: 1.48%
# Accuracy for Custom CNN: 1.49%
# Accuracy for Custom CNN: 1.52%
# Accuracy for Custom CNN: 1.52%
# Accuracy for Custom CNN: 1.54%
# Accuracy for Custom CNN: 1.55%
# Accuracy for Custom CNN: 1.57%
# Accuracy for Custom CNN: 1.57%
# Accuracy for Custom CNN: 1.57%
# Accuracy for Custom CNN: 1.58%
# Accuracy for Custom CNN: 1.59%
# Accuracy for Custom CNN: 1.61%
# Accuracy for Custom CNN: 1.63%
# Accuracy for Custom CNN: 1.64%
# Accuracy for Custom CNN: 1.65%
# Accuracy for Custom CNN: 1.65%
# Accuracy for Custom CNN: 1.68%
# Accuracy for Custom CNN: 1.70%
# Accuracy for Custom CNN: 1.70%
# Accuracy for Custom CNN: 1.70%
# Accuracy for Custom CNN: 1.72%
# Accuracy for Custom CNN: 1.73%
# Accuracy for Custom CNN: 1.73%
# Accuracy for Custom CNN: 1.74%
# Accuracy for Custom CNN: 1.76%
# Accuracy for Custom CNN: 1.77%
# Accuracy for Custom CNN: 1.77%
# Accuracy for Custom CNN: 1.77%
# Accuracy for Custom CNN: 1.77%
# Accuracy for Custom CNN: 1.79%
# Accuracy for Custom CNN: 1.79%
# Accuracy for Custom CNN: 1.79%
# Accuracy for Custom CNN: 1.80%
# Accuracy for Custom CNN: 1.82%
# Accuracy for Custom CNN: 1.82%
# Accuracy for Custom CNN: 1.83%
# Accuracy for Custom CNN: 1.84%
# Accuracy for Custom CNN: 1.84%
# Accuracy for Custom CNN: 1.84%
# Accuracy for Custom CNN: 1.85%
# Accuracy for Custom CNN: 1.85%
# Accuracy for Custom CNN: 1.86%
# Accuracy for Custom CNN: 1.86%
# Accuracy for Custom CNN: 1.86%
# Accuracy for Custom CNN: 1.88%
# Accuracy for Custom CNN: 1.90%
# Accuracy for Custom CNN: 1.92%
# Accuracy for Custom CNN: 1.93%
# Accuracy for Custom CNN: 1.95%
# Accuracy for Custom CNN: 1.95%
# Accuracy for Custom CNN: 1.96%
# Accuracy for Custom CNN: 1.98%
# Accuracy for Custom CNN: 1.99%
# Accuracy for Custom CNN: 2.01%
# Accuracy for Custom CNN: 2.02%
# Accuracy for Custom CNN: 2.02%
# Accuracy for Custom CNN: 2.03%
# Accuracy for Custom CNN: 2.05%
# Accuracy for Custom CNN: 2.06%
# Accuracy for Custom CNN: 2.08%
# Accuracy for Custom CNN: 2.09%
# Accuracy for Custom CNN: 2.09%
# Accuracy for Custom CNN: 2.09%
# Accuracy for Custom CNN: 2.11%
# Accuracy for Custom CNN: 2.16%
# Accuracy for Custom CNN: 2.17%
# Accuracy for Custom CNN: 2.17%
# Accuracy for Custom CNN: 2.20%
# Accuracy for Custom CNN: 2.21%
# Accuracy for Custom CNN: 2.23%
# Accuracy for Custom CNN: 2.24%
# Accuracy for Custom CNN: 2.26%
# Accuracy for Custom CNN: 2.26%
# Accuracy for Custom CNN: 2.27%
# Accuracy for Custom CNN: 2.29%
# Accuracy for Custom CNN: 2.30%
# Accuracy for Custom CNN: 2.30%
# Accuracy for Custom CNN: 2.30%
# Accuracy for Custom CNN: 2.30%
# Accuracy for Custom CNN: 2.32%
# Accuracy for Custom CNN: 2.34%
# Accuracy for Custom CNN: 2.34%
# Accuracy for Custom CNN: 2.39%
# Accuracy for Custom CNN: 2.40%
# Accuracy for Custom CNN: 2.41%
# Accuracy for Custom CNN: 2.42%
# Accuracy for Custom CNN: 2.43%
# Accuracy for Custom CNN: 2.43%
# Accuracy for Custom CNN: 2.44%
# Accuracy for Custom CNN: 2.44%
# Accuracy for Custom CNN: 2.44%
# Accuracy for Custom CNN: 2.44%
# Accuracy for Custom CNN: 2.44%
# Accuracy for Custom CNN: 2.44%
# Accuracy for Custom CNN: 2.46%
# Accuracy for Custom CNN: 2.46%
# Accuracy for Custom CNN: 2.47%
# Accuracy for Custom CNN: 2.49%
# Accuracy for Custom CNN: 2.51%
# Accuracy for Custom CNN: 2.52%
# Accuracy for Custom CNN: 2.52%
# Accuracy for Custom CNN: 2.52%
# Accuracy for Custom CNN: 2.52%
# Accuracy for Custom CNN: 2.54%
# Accuracy for Custom CNN: 2.56%
# Accuracy for Custom CNN: 2.57%
# Accuracy for Custom CNN: 2.58%
# Accuracy for Custom CNN: 2.60%
# Accuracy for Custom CNN: 2.63%
# Accuracy for Custom CNN: 2.65%
# Accuracy for Custom CNN: 2.65%
# Accuracy for Custom CNN: 2.66%
# Accuracy for Custom CNN: 2.68%
# Accuracy for Custom CNN: 2.69%
# Accuracy for Custom CNN: 2.70%
# Accuracy for Custom CNN: 2.71%
# Accuracy for Custom CNN: 2.76%
# Accuracy for Custom CNN: 2.77%
# Accuracy for Custom CNN: 2.78%
# Accuracy for Custom CNN: 2.78%
# Accuracy for Custom CNN: 2.79%
# Accuracy for Custom CNN: 2.80%
# Accuracy for Custom CNN: 2.83%
# Accuracy for Custom CNN: 2.84%
# Accuracy for Custom CNN: 2.85%
# Accuracy for Custom CNN: 2.86%
# Accuracy for Custom CNN: 2.86%
# Accuracy for Custom CNN: 2.86%
# Accuracy for Custom CNN: 2.87%
# Accuracy for Custom CNN: 2.87%
# Accuracy for Custom CNN: 2.87%
# Accuracy for Custom CNN: 2.88%
# Accuracy for Custom CNN: 2.90%
# Accuracy for Custom CNN: 2.92%
# Accuracy for Custom CNN: 2.92%
# Accuracy for Custom CNN: 2.93%
# Accuracy for Custom CNN: 2.94%
# Accuracy for Custom CNN: 2.94%
# Accuracy for Custom CNN: 2.95%
# Accuracy for Custom CNN: 2.95%
# Accuracy for Custom CNN: 2.97%
# Accuracy for Custom CNN: 2.97%
# Accuracy for Custom CNN: 2.98%
# Accuracy for Custom CNN: 2.99%
# Accuracy for Custom CNN: 2.99%
# Accuracy for Custom CNN: 2.99%
# Accuracy for Custom CNN: 3.00%
# Accuracy for Custom CNN: 3.01%
# Accuracy for Custom CNN: 3.03%
# Accuracy for Custom CNN: 3.04%
# Accuracy for Custom CNN: 3.05%
# Accuracy for Custom CNN: 3.08%
# Accuracy for Custom CNN: 3.09%
# Accuracy for Custom CNN: 3.11%
# Accuracy for Custom CNN: 3.12%
# Accuracy for Custom CNN: 3.13%
# Accuracy for Custom CNN: 3.15%
# Accuracy for Custom CNN: 3.15%
# Accuracy for Custom CNN: 3.15%
# Accuracy for Custom CNN: 3.18%
# Accuracy for Custom CNN: 3.18%
# Accuracy for Custom CNN: 3.19%
# Accuracy for Custom CNN: 3.21%
# Accuracy for Custom CNN: 3.24%
# Accuracy for Custom CNN: 3.24%
# Accuracy for Custom CNN: 3.24%
# Accuracy for Custom CNN: 3.24%
# Accuracy for Custom CNN: 3.26%
# Accuracy for Custom CNN: 3.27%
# Accuracy for Custom CNN: 3.29%
# Accuracy for Custom CNN: 3.29%
# Accuracy for Custom CNN: 3.30%
# Accuracy for Custom CNN: 3.31%
# Accuracy for Custom CNN: 3.32%
# Accuracy for Custom CNN: 3.32%
# Accuracy for Custom CNN: 3.34%
# Accuracy for Custom CNN: 3.35%
# Accuracy for Custom CNN: 3.36%
# Accuracy for Custom CNN: 3.37%
# Accuracy for Custom CNN: 3.39%
# Accuracy for Custom CNN: 3.40%
# Accuracy for Custom CNN: 3.41%
# Accuracy for Custom CNN: 3.43%
# Accuracy for Custom CNN: 3.45%
# Accuracy for Custom CNN: 3.46%
# Accuracy for Custom CNN: 3.46%
# Accuracy for Custom CNN: 3.47%
# Accuracy for Custom CNN: 3.47%
# Accuracy for Custom CNN: 3.49%
# Accuracy for Custom CNN: 3.49%
# Accuracy for Custom CNN: 3.52%
# Accuracy for Custom CNN: 3.52%
# Accuracy for Custom CNN: 3.52%
# Accuracy for Custom CNN: 3.54%
# Accuracy for Custom CNN: 3.55%
# Accuracy for Custom CNN: 3.57%
# Accuracy for Custom CNN: 3.58%
# Accuracy for Custom CNN: 3.58%
# Accuracy for Custom CNN: 3.59%
# Accuracy for Custom CNN: 3.59%
# Accuracy for Custom CNN: 3.60%
# Accuracy for Custom CNN: 3.61%
# Accuracy for Custom CNN: 3.63%
# Accuracy for Custom CNN: 3.64%
# Accuracy for Custom CNN: 3.67%
# Accuracy for Custom CNN: 3.68%
# Accuracy for Custom CNN: 3.71%
# Accuracy for Custom CNN: 3.73%
# Accuracy for Custom CNN: 3.75%
# Accuracy for Custom CNN: 3.76%
# Accuracy for Custom CNN: 3.76%
# Accuracy for Custom CNN: 3.76%
# Accuracy for Custom CNN: 3.77%
# Accuracy for Custom CNN: 3.78%
# Accuracy for Custom CNN: 3.78%
# Accuracy for Custom CNN: 3.78%
# Accuracy for Custom CNN: 3.81%
# Accuracy for Custom CNN: 3.81%
# Accuracy for Custom CNN: 3.82%
# Accuracy for Custom CNN: 3.84%
# Accuracy for Custom CNN: 3.84%
# Accuracy for Custom CNN: 3.84%
# Accuracy for Custom CNN: 3.85%
# Accuracy for Custom CNN: 3.87%
# Accuracy for Custom CNN: 3.91%
# Accuracy for Custom CNN: 3.91%
# Accuracy for Custom CNN: 3.95%
# Accuracy for Custom CNN: 3.96%
# Accuracy for Custom CNN: 3.97%
# Accuracy for Custom CNN: 3.98%
# Accuracy for Custom CNN: 3.98%
# Accuracy for Custom CNN: 3.98%
# Accuracy for Custom CNN: 3.98%
# Accuracy for Custom CNN: 3.98%
# Accuracy for Custom CNN: 3.99%
# Accuracy for Custom CNN: 4.00%
# Accuracy for Custom CNN: 4.00%
# Accuracy for Custom CNN: 4.01%
# Accuracy for Custom CNN: 4.01%
# Accuracy for Custom CNN: 4.03%
# Accuracy for Custom CNN: 4.05%
# Accuracy for Custom CNN: 4.08%
# Accuracy for Custom CNN: 4.08%
# Accuracy for Custom CNN: 4.09%
# Accuracy for Custom CNN: 4.11%
# Accuracy for Custom CNN: 4.14%
# Accuracy for Custom CNN: 4.16%
# Accuracy for Custom CNN: 4.17%
# Accuracy for Custom CNN: 4.19%
# Accuracy for Custom CNN: 4.20%
# Accuracy for Custom CNN: 4.21%
# Accuracy for Custom CNN: 4.21%
# Accuracy for Custom CNN: 4.21%
# Accuracy for Custom CNN: 4.21%
# Accuracy for Custom CNN: 4.22%
# Accuracy for Custom CNN: 4.25%
# Accuracy for Custom CNN: 4.25%
# Accuracy for Custom CNN: 4.27%
# Accuracy for Custom CNN: 4.29%
# Accuracy for Custom CNN: 4.32%
# Accuracy for Custom CNN: 4.32%
# Accuracy for Custom CNN: 4.33%
# Accuracy for Custom CNN: 4.34%
# Accuracy for Custom CNN: 4.34%
# Accuracy for Custom CNN: 4.34%
# Accuracy for Custom CNN: 4.35%
# Accuracy for Custom CNN: 4.38%
# Accuracy for Custom CNN: 4.39%
# Accuracy for Custom CNN: 4.39%
# Accuracy for Custom CNN: 4.39%
# Accuracy for Custom CNN: 4.40%
# Accuracy for Custom CNN: 4.42%
# Accuracy for Custom CNN: 4.43%
# Accuracy for Custom CNN: 4.45%
# Accuracy for Custom CNN: 4.47%
# Accuracy for Custom CNN: 4.47%
# Accuracy for Custom CNN: 4.47%
# Accuracy for Custom CNN: 4.47%
# Accuracy for Custom CNN: 4.48%
# Accuracy for Custom CNN: 4.49%
# Accuracy for Custom CNN: 4.50%
# Accuracy for Custom CNN: 4.52%
# Accuracy for Custom CNN: 4.55%
# Accuracy for Custom CNN: 4.57%
# Accuracy for Custom CNN: 4.61%
# Accuracy for Custom CNN: 4.61%
# Accuracy for Custom CNN: 4.63%
# Accuracy for Custom CNN: 4.64%
# Accuracy for Custom CNN: 4.66%
# Accuracy for Custom CNN: 4.67%
# Accuracy for Custom CNN: 4.67%
# Accuracy for Custom CNN: 4.69%
# Accuracy for Custom CNN: 4.70%
# Accuracy for Custom CNN: 4.70%
# Accuracy for Custom CNN: 4.71%
# Accuracy for Custom CNN: 4.73%
# Accuracy for Custom CNN: 4.74%
# Accuracy for Custom CNN: 4.76%
# Accuracy for Custom CNN: 4.80%
# Accuracy for Custom CNN: 4.82%
# Accuracy for Custom CNN: 4.85%
# Accuracy for Custom CNN: 4.86%
# Accuracy for Custom CNN: 4.88%
# Accuracy for Custom CNN: 4.88%
# Accuracy for Custom CNN: 4.89%
# Accuracy for Custom CNN: 4.90%
# Accuracy for Custom CNN: 4.90%
# Accuracy for Custom CNN: 4.93%
# Accuracy for Custom CNN: 4.94%
# Accuracy for Custom CNN: 4.94%
# Accuracy for Custom CNN: 4.95%
# Accuracy for Custom CNN: 4.98%
# Accuracy for Custom CNN: 4.99%
# Accuracy for Custom CNN: 5.00%
# Accuracy for Custom CNN: 5.02%
# Accuracy for Custom CNN: 5.03%
# Accuracy for Custom CNN: 5.03%
# Accuracy for Custom CNN: 5.03%
# Accuracy for Custom CNN: 5.03%
# Accuracy for Custom CNN: 5.04%
# Accuracy for Custom CNN: 5.04%
# Accuracy for Custom CNN: 5.05%
# Accuracy for Custom CNN: 5.05%
# Accuracy for Custom CNN: 5.06%
# Accuracy for Custom CNN: 5.06%
# Accuracy for Custom CNN: 5.06%
# Accuracy for Custom CNN: 5.07%
# Accuracy for Custom CNN: 5.07%
# Accuracy for Custom CNN: 5.07%
# Accuracy for Custom CNN: 5.07%
# Accuracy for Custom CNN: 5.08%
# Accuracy for Custom CNN: 5.09%
# Accuracy for Custom CNN: 5.10%
# Accuracy for Custom CNN: 5.12%
# Accuracy for Custom CNN: 5.14%
# Accuracy for Custom CNN: 5.14%
# Accuracy for Custom CNN: 5.14%
# Accuracy for Custom CNN: 5.16%
# Accuracy for Custom CNN: 5.17%
# Accuracy for Custom CNN: 5.20%
# Accuracy for Custom CNN: 5.22%
# Accuracy for Custom CNN: 5.25%
# Accuracy for Custom CNN: 5.25%
# Accuracy for Custom CNN: 5.25%
# Accuracy for Custom CNN: 5.25%
# Accuracy for Custom CNN: 5.27%
# Accuracy for Custom CNN: 5.30%
# Accuracy for Custom CNN: 5.30%
# Accuracy for Custom CNN: 5.33%
# Accuracy for Custom CNN: 5.35%
# Accuracy for Custom CNN: 5.36%
# Accuracy for Custom CNN: 5.37%
# Accuracy for Custom CNN: 5.39%
# Accuracy for Custom CNN: 5.40%
# Accuracy for Custom CNN: 5.42%
# Accuracy for Custom CNN: 5.42%
# Accuracy for Custom CNN: 5.44%
# Accuracy for Custom CNN: 5.45%
# Accuracy for Custom CNN: 5.47%
# Accuracy for Custom CNN: 5.47%
# Accuracy for Custom CNN: 5.47%
# Accuracy for Custom CNN: 5.48%
# Accuracy for Custom CNN: 5.48%
# Accuracy for Custom CNN: 5.48%
# Accuracy for Custom CNN: 5.48%
# Accuracy for Custom CNN: 5.49%
# Accuracy for Custom CNN: 5.52%
# Accuracy for Custom CNN: 5.54%
# Accuracy for Custom CNN: 5.57%
# Accuracy for Custom CNN: 5.57%
# Accuracy for Custom CNN: 5.57%
# Accuracy for Custom CNN: 5.59%
# Accuracy for Custom CNN: 5.60%
# Accuracy for Custom CNN: 5.62%
# Accuracy for Custom CNN: 5.65%
# Accuracy for Custom CNN: 5.66%
# Accuracy for Custom CNN: 5.68%
# Accuracy for Custom CNN: 5.68%
# Accuracy for Custom CNN: 5.70%
# Accuracy for Custom CNN: 5.71%
# Accuracy for Custom CNN: 5.71%
# Accuracy for Custom CNN: 5.72%
# Accuracy for Custom CNN: 5.74%
# Accuracy for Custom CNN: 5.75%
# Accuracy for Custom CNN: 5.76%
# Accuracy for Custom CNN: 5.77%
# Accuracy for Custom CNN: 5.78%
# Accuracy for Custom CNN: 5.78%
# Accuracy for Custom CNN: 5.79%
# Accuracy for Custom CNN: 5.80%
# Accuracy for Custom CNN: 5.84%
# Accuracy for Custom CNN: 5.84%
# Accuracy for Custom CNN: 5.86%
# Accuracy for Custom CNN: 5.87%
# Accuracy for Custom CNN: 5.88%
# Accuracy for Custom CNN: 5.89%
# Accuracy for Custom CNN: 5.90%
# Accuracy for Custom CNN: 5.91%
# Accuracy for Custom CNN: 5.91%
# Accuracy for Custom CNN: 5.92%
# Accuracy for Custom CNN: 5.93%
# Accuracy for Custom CNN: 5.95%
# Accuracy for Custom CNN: 5.96%
# Accuracy for Custom CNN: 5.97%
# Accuracy for Custom CNN: 5.98%
# Accuracy for Custom CNN: 5.98%
# Accuracy for Custom CNN: 6.01%
# Accuracy for Custom CNN: 6.01%
# Accuracy for Custom CNN: 6.02%
# Accuracy for Custom CNN: 6.03%
# Accuracy for Custom CNN: 6.04%
# Accuracy for Custom CNN: 6.04%
# Accuracy for Custom CNN: 6.07%
# Accuracy for Custom CNN: 6.09%
# Accuracy for Custom CNN: 6.10%
# Accuracy for Custom CNN: 6.10%
# Accuracy for Custom CNN: 6.11%
# Accuracy for Custom CNN: 6.12%
# Accuracy for Custom CNN: 6.13%
# Accuracy for Custom CNN: 6.14%
# Accuracy for Custom CNN: 6.15%
# Accuracy for Custom CNN: 6.16%
# Accuracy for Custom CNN: 6.17%
# Accuracy for Custom CNN: 6.17%
# Accuracy for Custom CNN: 6.18%
# Accuracy for Custom CNN: 6.19%
# Accuracy for Custom CNN: 6.21%
# Accuracy for Custom CNN: 6.23%
# Accuracy for Custom CNN: 6.24%
# Accuracy for Custom CNN: 6.25%
# Accuracy for Custom CNN: 6.27%
# Accuracy for Custom CNN: 6.28%
# Accuracy for Custom CNN: 6.29%
# Accuracy for Custom CNN: 6.31%
# Accuracy for Custom CNN: 6.33%
# Accuracy for Custom CNN: 6.34%
# Accuracy for Custom CNN: 6.37%
# Accuracy for Custom CNN: 6.38%
# Accuracy for Custom CNN: 6.38%
# Accuracy for Custom CNN: 6.39%
# Accuracy for Custom CNN: 6.41%
# Accuracy for Custom CNN: 6.42%
# Accuracy for Custom CNN: 6.43%
# Accuracy for Custom CNN: 6.43%
# Accuracy for Custom CNN: 6.45%
# Accuracy for Custom CNN: 6.47%
# Accuracy for Custom CNN: 6.48%
# Accuracy for Custom CNN: 6.50%
# Accuracy for Custom CNN: 6.51%
# Accuracy for Custom CNN: 6.52%
# Accuracy for Custom CNN: 6.53%
# Accuracy for Custom CNN: 6.53%
# Accuracy for Custom CNN: 6.53%
# Accuracy for Custom CNN: 6.54%
# Accuracy for Custom CNN: 6.56%
# Accuracy for Custom CNN: 6.57%
# Accuracy for Custom CNN: 6.58%
# Accuracy for Custom CNN: 6.59%
# Accuracy for Custom CNN: 6.60%
# Accuracy for Custom CNN: 6.62%
# Accuracy for Custom CNN: 6.63%
# Accuracy for Custom CNN: 6.64%
# Accuracy for Custom CNN: 6.65%
# Accuracy for Custom CNN: 6.65%
# Accuracy for Custom CNN: 6.67%
# Accuracy for Custom CNN: 6.68%
# Accuracy for Custom CNN: 6.69%
# Accuracy for Custom CNN: 6.69%
# Accuracy for Custom CNN: 6.71%
# Accuracy for Custom CNN: 6.73%
# Accuracy for Custom CNN: 6.75%
# Accuracy for Custom CNN: 6.76%
# Accuracy for Custom CNN: 6.78%
# Accuracy for Custom CNN: 6.78%
# Accuracy for Custom CNN: 6.79%
# Accuracy for Custom CNN: 6.80%
# Accuracy for Custom CNN: 6.81%
# Accuracy for Custom CNN: 6.81%
# Accuracy for Custom CNN: 6.83%
# Accuracy for Custom CNN: 6.84%
# Accuracy for Custom CNN: 6.86%
# Accuracy for Custom CNN: 6.88%
# Accuracy for Custom CNN: 6.89%
# Accuracy for Custom CNN: 6.89%
# Accuracy for Custom CNN: 6.89%
# Accuracy for Custom CNN: 6.90%
# Accuracy for Custom CNN: 6.91%
# Accuracy for Custom CNN: 6.93%
# Accuracy for Custom CNN: 6.94%
# Accuracy for Custom CNN: 6.95%
# Accuracy for Custom CNN: 6.96%
# Accuracy for Custom CNN: 6.98%
# Accuracy for Custom CNN: 7.00%
# Accuracy for Custom CNN: 7.01%
# Accuracy for Custom CNN: 7.02%
# Accuracy for Custom CNN: 7.03%
# Accuracy for Custom CNN: 7.04%
# Accuracy for Custom CNN: 7.05%
# Accuracy for Custom CNN: 7.05%
# Accuracy for Custom CNN: 7.06%
# Accuracy for Custom CNN: 7.07%
# Accuracy for Custom CNN: 7.08%
# Accuracy for Custom CNN: 7.08%
# Accuracy for Custom CNN: 7.10%
# Accuracy for Custom CNN: 7.14%
# Accuracy for Custom CNN: 7.14%
# Accuracy for Custom CNN: 7.15%
# Accuracy for Custom CNN: 7.15%
# Accuracy for Custom CNN: 7.17%
# Accuracy for Custom CNN: 7.17%
# Accuracy for Custom CNN: 7.17%
# Accuracy for Custom CNN: 7.18%
# Accuracy for Custom CNN: 7.19%
# Accuracy for Custom CNN: 7.21%
# Accuracy for Custom CNN: 7.22%
# Accuracy for Custom CNN: 7.22%
# Accuracy for Custom CNN: 7.23%
# Accuracy for Custom CNN: 7.23%
# Accuracy for Custom CNN: 7.25%
# Accuracy for Custom CNN: 7.25%
# Accuracy for Custom CNN: 7.26%
# Accuracy for Custom CNN: 7.28%
# Accuracy for Custom CNN: 7.29%
# Accuracy for Custom CNN: 7.29%
# Accuracy for Custom CNN: 7.31%
# Accuracy for Custom CNN: 7.32%
# Accuracy for Custom CNN: 7.33%
# Accuracy for Custom CNN: 7.34%
# Accuracy for Custom CNN: 7.35%
# Accuracy for Custom CNN: 7.37%
# Accuracy for Custom CNN: 7.37%
# Accuracy for Custom CNN: 7.39%
# Accuracy for Custom CNN: 7.40%
# Accuracy for Custom CNN: 7.41%
# Accuracy for Custom CNN: 7.42%
# Accuracy for Custom CNN: 7.44%
# Accuracy for Custom CNN: 7.45%
# Accuracy for Custom CNN: 7.45%
# Accuracy for Custom CNN: 7.46%
# Accuracy for Custom CNN: 7.46%
# Accuracy for Custom CNN: 7.46%
# Accuracy for Custom CNN: 7.48%
# Accuracy for Custom CNN: 7.49%
# Accuracy for Custom CNN: 7.52%
# Accuracy for Custom CNN: 7.53%
# Accuracy for Custom CNN: 7.54%
# Accuracy for Custom CNN: 7.55%
# Accuracy for Custom CNN: 7.56%
# Accuracy for Custom CNN: 7.59%
# Accuracy for Custom CNN: 7.62%
# Accuracy for Custom CNN: 7.63%
# Accuracy for Custom CNN: 7.64%
# Accuracy for Custom CNN: 7.65%
# Accuracy for Custom CNN: 7.68%
# Accuracy for Custom CNN: 7.69%
# Accuracy for Custom CNN: 7.71%
# Accuracy for Custom CNN: 7.74%
# Accuracy for Custom CNN: 7.74%
# Accuracy for Custom CNN: 7.74%
# Accuracy for Custom CNN: 7.76%
# Accuracy for Custom CNN: 7.77%
# Accuracy for Custom CNN: 7.78%
# Accuracy for Custom CNN: 7.79%
# Accuracy for Custom CNN: 7.80%
# Accuracy for Custom CNN: 7.80%
# Accuracy for Custom CNN: 7.81%
# Accuracy for Custom CNN: 7.81%
# Accuracy for Custom CNN: 7.83%
# Accuracy for Custom CNN: 7.83%
# Accuracy for Custom CNN: 7.84%
# Accuracy for Custom CNN: 7.85%
# Accuracy for Custom CNN: 7.87%
# Accuracy for Custom CNN: 7.89%
# Accuracy for Custom CNN: 7.90%
# Accuracy for Custom CNN: 7.91%
# Accuracy for Custom CNN: 7.92%
# Accuracy for Custom CNN: 7.92%
# Accuracy for Custom CNN: 7.94%
# Accuracy for Custom CNN: 7.95%
# Accuracy for Custom CNN: 7.95%
# Accuracy for Custom CNN: 7.95%
# Accuracy for Custom CNN: 7.97%
# Accuracy for Custom CNN: 7.99%
# Accuracy for Custom CNN: 8.00%
# Accuracy for Custom CNN: 8.00%
# Accuracy for Custom CNN: 8.01%
# Accuracy for Custom CNN: 8.02%
# Accuracy for Custom CNN: 8.03%
# Accuracy for Custom CNN: 8.04%
# Accuracy for Custom CNN: 8.05%
# Accuracy for Custom CNN: 8.06%
# Accuracy for Custom CNN: 8.06%
# Accuracy for Custom CNN: 8.06%
# Accuracy for Custom CNN: 8.07%
# Accuracy for Custom CNN: 8.08%
# Accuracy for Custom CNN: 8.08%
# Accuracy for Custom CNN: 8.09%
# Accuracy for Custom CNN: 8.11%
# Accuracy for Custom CNN: 8.14%
# Accuracy for Custom CNN: 8.15%
# Accuracy for Custom CNN: 8.16%
# Accuracy for Custom CNN: 8.16%
# Accuracy for Custom CNN: 8.17%
# Accuracy for Custom CNN: 8.20%
# Accuracy for Custom CNN: 8.21%
# Accuracy for Custom CNN: 8.22%
# Accuracy for Custom CNN: 8.23%
# Accuracy for Custom CNN: 8.24%
# Accuracy for Custom CNN: 8.25%
# Accuracy for Custom CNN: 8.26%
# Accuracy for Custom CNN: 8.28%
# Accuracy for Custom CNN: 8.29%
# Accuracy for Custom CNN: 8.30%
# Accuracy for Custom CNN: 8.32%
# Accuracy for Custom CNN: 8.32%
# Accuracy for Custom CNN: 8.34%
# Accuracy for Custom CNN: 8.35%
# Accuracy for Custom CNN: 8.35%
# Accuracy for Custom CNN: 8.36%
# Accuracy for Custom CNN: 8.36%
# Accuracy for Custom CNN: 8.38%
# Accuracy for Custom CNN: 8.39%
# Accuracy for Custom CNN: 8.41%
# Accuracy for Custom CNN: 8.43%
# Accuracy for Custom CNN: 8.43%
# Accuracy for Custom CNN: 8.45%
# Accuracy for Custom CNN: 8.46%
# Accuracy for Custom CNN: 8.48%
# Accuracy for Custom CNN: 8.48%
# Accuracy for Custom CNN: 8.49%
# Accuracy for Custom CNN: 8.49%
# Accuracy for Custom CNN: 8.50%
# Accuracy for Custom CNN: 8.51%
# Accuracy for Custom CNN: 8.52%
# Accuracy for Custom CNN: 8.52%
# Accuracy for Custom CNN: 8.52%
# Accuracy for Custom CNN: 8.53%
# Accuracy for Custom CNN: 8.56%
# Accuracy for Custom CNN: 8.56%
# Accuracy for Custom CNN: 8.58%
# Accuracy for Custom CNN: 8.59%
# Accuracy for Custom CNN: 8.61%
# Accuracy for Custom CNN: 8.62%
# Accuracy for Custom CNN: 8.63%
# Accuracy for Custom CNN: 8.65%
# Accuracy for Custom CNN: 8.65%
# Accuracy for Custom CNN: 8.66%
# Accuracy for Custom CNN: 8.68%
# Accuracy for Custom CNN: 8.68%
# Accuracy for Custom CNN: 8.69%
# Accuracy for Custom CNN: 8.69%
# Accuracy for Custom CNN: 8.70%
# Accuracy for Custom CNN: 8.71%
# Accuracy for Custom CNN: 8.74%
# Accuracy for Custom CNN: 8.75%
# Accuracy for Custom CNN: 8.76%
# Accuracy for Custom CNN: 8.76%
# Accuracy for Custom CNN: 8.76%
# Accuracy for Custom CNN: 8.76%
# Accuracy for Custom CNN: 8.78%
# Accuracy for Custom CNN: 8.79%
# Accuracy for Custom CNN: 8.81%
# Accuracy for Custom CNN: 8.83%
# Accuracy for Custom CNN: 8.84%
# Accuracy for Custom CNN: 8.86%
# Accuracy for Custom CNN: 8.87%
# Accuracy for Custom CNN: 8.88%
# Accuracy for Custom CNN: 8.89%
# Accuracy for Custom CNN: 8.89%
# Accuracy for Custom CNN: 8.90%
# Accuracy for Custom CNN: 8.93%
# Accuracy for Custom CNN: 8.94%
# Accuracy for Custom CNN: 8.96%
# Accuracy for Custom CNN: 8.98%
# Accuracy for Custom CNN: 8.99%
# Accuracy for Custom CNN: 9.00%
# Accuracy for Custom CNN: 9.01%
# Accuracy for Custom CNN: 9.02%
# Accuracy for Custom CNN: 9.03%
# Accuracy for Custom CNN: 9.04%
# Accuracy for Custom CNN: 9.05%
# Accuracy for Custom CNN: 9.07%
# Accuracy for Custom CNN: 9.07%
# Accuracy for Custom CNN: 9.09%
# Accuracy for Custom CNN: 9.09%
# Accuracy for Custom CNN: 9.11%
# Accuracy for Custom CNN: 9.12%
# Accuracy for Custom CNN: 9.13%
# Accuracy for Custom CNN: 9.14%
# Accuracy for Custom CNN: 9.16%
# Accuracy for Custom CNN: 9.18%
# Accuracy for Custom CNN: 9.19%
# Accuracy for Custom CNN: 9.21%
# Accuracy for Custom CNN: 9.22%
# Accuracy for Custom CNN: 9.23%
# Accuracy for Custom CNN: 9.23%
# Accuracy for Custom CNN: 9.24%
# Accuracy for Custom CNN: 9.26%
# Accuracy for Custom CNN: 9.26%
# Accuracy for Custom CNN: 9.27%
# Accuracy for Custom CNN: 9.27%
# Accuracy for Custom CNN: 9.27%
# Accuracy for Custom CNN: 9.28%
# Accuracy for Custom CNN: 9.29%
# Accuracy for Custom CNN: 9.32%
# Accuracy for Custom CNN: 9.33%
# Accuracy for Custom CNN: 9.34%
# Accuracy for Custom CNN: 9.36%
# Accuracy for Custom CNN: 9.36%
# Accuracy for Custom CNN: 9.38%
# Accuracy for Custom CNN: 9.38%
# Accuracy for Custom CNN: 9.41%
# Accuracy for Custom CNN: 9.41%
# Accuracy for Custom CNN: 9.42%
# Accuracy for Custom CNN: 9.42%
# Accuracy for Custom CNN: 9.44%
# Accuracy for Custom CNN: 9.45%
# Accuracy for Custom CNN: 9.47%
# Accuracy for Custom CNN: 9.48%
# Accuracy for Custom CNN: 9.48%
# Accuracy for Custom CNN: 9.50%
# Accuracy for Custom CNN: 9.50%
# Accuracy for Custom CNN: 9.51%
# Accuracy for Custom CNN: 9.53%
# Accuracy for Custom CNN: 9.55%
# Accuracy for Custom CNN: 9.57%
# Accuracy for Custom CNN: 9.58%
# Accuracy for Custom CNN: 9.59%
# Accuracy for Custom CNN: 9.59%
# Accuracy for Custom CNN: 9.60%
# Accuracy for Custom CNN: 9.62%
# Accuracy for Custom CNN: 9.63%
# Accuracy for Custom CNN: 9.63%
# Accuracy for Custom CNN: 9.64%
# Accuracy for Custom CNN: 9.66%
# Accuracy for Custom CNN: 9.70%
# Accuracy for Custom CNN: 9.71%
# Accuracy for Custom CNN: 9.72%
# Accuracy for Custom CNN: 9.73%
# Accuracy for Custom CNN: 9.74%
# Accuracy for Custom CNN: 9.74%
# Accuracy for Custom CNN: 9.76%
# Accuracy for Custom CNN: 9.76%
# Accuracy for Custom CNN: 9.76%
# Accuracy for Custom CNN: 9.78%
# Accuracy for Custom CNN: 9.78%
# Accuracy for Custom CNN: 9.81%
# Accuracy for Custom CNN: 9.82%
# Accuracy for Custom CNN: 9.83%
# Accuracy for Custom CNN: 9.84%
# Accuracy for Custom CNN: 9.85%
# Accuracy for Custom CNN: 9.86%
# Accuracy for Custom CNN: 9.87%
# Accuracy for Custom CNN: 9.90%
# Accuracy for Custom CNN: 9.90%
# Accuracy for Custom CNN: 9.92%
# Accuracy for Custom CNN: 9.93%
# Accuracy for Custom CNN: 9.94%
# Accuracy for Custom CNN: 9.95%
# Accuracy for Custom CNN: 9.95%
# Accuracy for Custom CNN: 9.96%
# Accuracy for Custom CNN: 9.97%
# Accuracy for Custom CNN: 9.98%
# Accuracy for Custom CNN: 9.98%
# Accuracy for Custom CNN: 9.98%
# Accuracy for Custom CNN: 9.98%
# Accuracy for Custom CNN: 9.99%
# Accuracy for Custom CNN: 10.00%
# Accuracy for Custom CNN: 10.02%
# Accuracy for Custom CNN: 10.03%
# Accuracy for Custom CNN: 10.04%
# Accuracy for Custom CNN: 10.05%
# Accuracy for Custom CNN: 10.06%
# Accuracy for Custom CNN: 10.07%
# Accuracy for Custom CNN: 10.09%
# Accuracy for Custom CNN: 10.09%
# Accuracy for Custom CNN: 10.09%
# Accuracy for Custom CNN: 10.09%
# Accuracy for Custom CNN: 10.12%
# Accuracy for Custom CNN: 10.15%
# Accuracy for Custom CNN: 10.16%
# Accuracy for Custom CNN: 10.19%
# Accuracy for Custom CNN: 10.20%
# Accuracy for Custom CNN: 10.21%
# Accuracy for Custom CNN: 10.23%
# Accuracy for Custom CNN: 10.24%
# Accuracy for Custom CNN: 10.25%
# Accuracy for Custom CNN: 10.26%
# Accuracy for Custom CNN: 10.27%
# Accuracy for Custom CNN: 10.28%
# Accuracy for Custom CNN: 10.30%
# Accuracy for Custom CNN: 10.30%
# Accuracy for Custom CNN: 10.31%
# Accuracy for Custom CNN: 10.34%
# Accuracy for Custom CNN: 10.34%
# Accuracy for Custom CNN: 10.36%
# Accuracy for Custom CNN: 10.37%
# Accuracy for Custom CNN: 10.37%
# Accuracy for Custom CNN: 10.38%
# Accuracy for Custom CNN: 10.39%
# Accuracy for Custom CNN: 10.40%
# Accuracy for Custom CNN: 10.41%
# Accuracy for Custom CNN: 10.41%
# Accuracy for Custom CNN: 10.42%
# Accuracy for Custom CNN: 10.43%
# Accuracy for Custom CNN: 10.45%
# Accuracy for Custom CNN: 10.46%
# Accuracy for Custom CNN: 10.47%
# Accuracy for Custom CNN: 10.48%
# Accuracy for Custom CNN: 10.49%
# Accuracy for Custom CNN: 10.51%
# Accuracy for Custom CNN: 10.52%
# Accuracy for Custom CNN: 10.53%
# Accuracy for Custom CNN: 10.54%
# Accuracy for Custom CNN: 10.56%
# Accuracy for Custom CNN: 10.58%
# Accuracy for Custom CNN: 10.59%
# Accuracy for Custom CNN: 10.60%
# Accuracy for Custom CNN: 10.61%
# Accuracy for Custom CNN: 10.62%
# Accuracy for Custom CNN: 10.63%
# Accuracy for Custom CNN: 10.65%
# Accuracy for Custom CNN: 10.66%
# Accuracy for Custom CNN: 10.66%
# Accuracy for Custom CNN: 10.69%
# Accuracy for Custom CNN: 10.71%
# Accuracy for Custom CNN: 10.71%
# Accuracy for Custom CNN: 10.72%
# Accuracy for Custom CNN: 10.72%
# Accuracy for Custom CNN: 10.74%
# Accuracy for Custom CNN: 10.75%
# Accuracy for Custom CNN: 10.76%
# Accuracy for Custom CNN: 10.77%
# Accuracy for Custom CNN: 10.78%
# Accuracy for Custom CNN: 10.78%
# Accuracy for Custom CNN: 10.80%
# Accuracy for Custom CNN: 10.81%
# Accuracy for Custom CNN: 10.81%
# Accuracy for Custom CNN: 10.82%
# Accuracy for Custom CNN: 10.82%
# Accuracy for Custom CNN: 10.86%
# Accuracy for Custom CNN: 10.87%
# Accuracy for Custom CNN: 10.88%
# Accuracy for Custom CNN: 10.89%
# Accuracy for Custom CNN: 10.89%
# Accuracy for Custom CNN: 10.93%
# Accuracy for Custom CNN: 10.95%
# Accuracy for Custom CNN: 10.96%
# Accuracy for Custom CNN: 10.97%
# Accuracy for Custom CNN: 10.99%
# Accuracy for Custom CNN: 11.00%
# Accuracy for Custom CNN: 11.01%
# Accuracy for Custom CNN: 11.02%
# Accuracy for Custom CNN: 11.03%
# Accuracy for Custom CNN: 11.04%
# Accuracy for Custom CNN: 11.04%
# Accuracy for Custom CNN: 11.04%
# Accuracy for Custom CNN: 11.05%
# Accuracy for Custom CNN: 11.07%
# Accuracy for Custom CNN: 11.07%
# Accuracy for Custom CNN: 11.10%
# Accuracy for Custom CNN: 11.11%
# Accuracy for Custom CNN: 11.13%
# Accuracy for Custom CNN: 11.13%
# Accuracy for Custom CNN: 11.15%
# Accuracy for Custom CNN: 11.19%
# Accuracy for Custom CNN: 11.19%
# Accuracy for Custom CNN: 11.19%
# Accuracy for Custom CNN: 11.21%
# Accuracy for Custom CNN: 11.21%
# Accuracy for Custom CNN: 11.23%
# Accuracy for Custom CNN: 11.24%
# Accuracy for Custom CNN: 11.25%
# Accuracy for Custom CNN: 11.26%
# Accuracy for Custom CNN: 11.27%
# Accuracy for Custom CNN: 11.28%
# Accuracy for Custom CNN: 11.31%
# Accuracy for Custom CNN: 11.32%
# Accuracy for Custom CNN: 11.33%
# Accuracy for Custom CNN: 11.34%
# Accuracy for Custom CNN: 11.35%

# %% [markdown]
# #### Pretrained Model

# %%
import torch.optim as optim
from torchvision import models

pretrained_model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

pretrained_model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)

pretrained_model.fc = nn.Linear(pretrained_model.fc.in_features, 10)

loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(pretrained_model.parameters(), lr=0.0001)

for param in pretrained_model.parameters():
    param.requires_grad = False

for param in pretrained_model.fc.parameters():
    param.requires_grad = True

test_correct = 0

for epoch in range(5):
    total_loss = 0
    for i, (X_train, y_train) in enumerate(train_loader):
        y_prediction = pretrained_model(X_train)
        loss = loss_function(y_prediction, y_train)
        total_loss += loss
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f'epoch: {epoch + 1}     loss: {total_loss / len(train_loader) :.5f}')

with torch.no_grad():
    for i, (X_test, y_test) in enumerate(test_loader):
        y_value = pretrained_model(X_test)
        loss = loss_function(y_value, y_test)

        test_correct += (torch.max(y_value, 1)[1] == y_test).sum()
        
print(f'Accuracy for Pretrained Model: {test_correct/len(test_data)*100 :.2f}%')
# Out:
# epoch: 1     loss: 1.69756
# epoch: 2     loss: 1.44742
# epoch: 3     loss: 1.40494
# epoch: 4     loss: 1.38315
# epoch: 5     loss: 1.37291
# Accuracy for Pretrained Model: 55.96%

# %% [markdown]
# #### Active Learning Implementation

# %%
model = ConvolutionalNeuralNetwork()
model
# Out:
# ConvolutionalNeuralNetwork(
#   (conv1): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 25, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=900, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=10, bias=True)
# )

# %%
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.01)

def calculate_least_confidence(outputs):
    probabilities = F.softmax(outputs, dim=1)
    least_confidence = 1 - probabilities.max(dim=1).values.detach().cpu().numpy()
    return least_confidence

def calculate_prediction_entropy(outputs):
    probabilities = F.softmax(outputs, dim=1)
    current_probs = probabilities.clone().detach()
    current_probs[current_probs == 0] = 1e-10
    prediction_entropy = -torch.sum(current_probs * torch.log(current_probs), dim=1).detach().cpu().numpy()
    return prediction_entropy
    
def calculate_margin_sampling(outputs):
    probabilities = F.softmax(outputs, dim=1)
    sorted_probs, _ = probabilities.sort(dim=1, descending=True)
    margin_sampling = (sorted_probs[:, 0] - sorted_probs[:, 1]).detach().cpu().numpy()
    return margin_sampling

def calculate_cosine_similarity(features, m=5):
    feature_distances = pairwise_distances(features.cpu().detach().numpy(), metric='cosine')
    cosine_similarity = 1 - feature_distances[:, 1:m+1].mean(axis=1)
    return cosine_similarity

def calculate_l2_norm(features, m=5):
    l2_distances = pairwise_distances(features.cpu().detach().numpy(), metric='euclidean')
    l2_norm = l2_distances[:, 1:m+1].mean(axis=1)
    return l2_norm

def calculate_kl_divergence(outputs, feature_distances, m=5):
    kl_divergence = []
    for i in range(len(outputs)):
        current_sample_prob = F.softmax(outputs[i], dim=0)
        neighbor_indices = feature_distances[i, 1:m+1].astype(int)
        neighbors_prob = F.softmax(torch.mean(F.softmax(outputs[neighbor_indices], dim=1), dim=0), dim=0)
        kl_divergence.append(F.kl_div(torch.log(current_sample_prob), neighbors_prob, reduction='batchmean').item())
    return kl_divergence

methods = ['least confidence', 'prediction entropy', 'margin sampling','cosine similarity', 'l2 norm', 'kl divergence']

results = {method: [] for method in methods}

for method in methods:
    
    labeled_set = list(range(1000))
    unlabeled_set = list(range(1000, len(train_data)))

    for iteration in range(3):
        
        labeled_loader = torch.utils.data.DataLoader(torch.utils.data.Subset(train_data, labeled_set), batch_size=10, shuffle=True)
        unlabeled_loader = torch.utils.data.DataLoader(torch.utils.data.Subset(train_data, unlabeled_set), batch_size=10, shuffle=False)

        for epochs in range(5):
            for data in labeled_loader:
                X_train, y_train = data
                y_prediction = model(X_train)
                loss = loss_function(y_prediction, y_train)
        
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

        test_correct = 0
        with torch.no_grad():
            for i, (X_test, y_test) in enumerate(test_loader):
                y_value = model(X_test)
                loss = loss_function(y_value, y_test)

                test_correct += (torch.max(y_value, 1)[1] == y_test).sum()

        print(f'method: {method}     iteration: {iteration + 1}     accuracy: {test_correct/len(test_data)*100 :.2f}%')
        accuracy = test_correct / len(test_data) * 100
        results[method].append(round(accuracy.item(), 2))

        unlabeled_dataset = unlabeled_loader.dataset
        unlabeled_subset = torch.utils.data.Subset(unlabeled_dataset, range(1000))
        unlabeled_subset_loader = torch.utils.data.DataLoader(unlabeled_subset, batch_size=unlabeled_loader.batch_size, shuffle=False)
        
        outputs_list = []
        features_list = []
        for data in unlabeled_subset:
            X, y = data
            outputs = model(X)

            features = model.extract_features(X)

            outputs_list.append(outputs)
            features_list.append(features)

        outputs = torch.cat(outputs_list, dim=0)
        features = torch.cat(features_list, dim=0)

        if (method == 'least confidence'):
            least_confidence = calculate_least_confidence(outputs)
            scores = np.array(least_confidence)
        elif (method == 'prediction entropy'):
            prediction_entropy = calculate_prediction_entropy(outputs)
            scores = -np.array(prediction_entropy)
        elif (method == 'margin sampling'):
            margin_sampling = calculate_margin_sampling(outputs)
            scores = np.array(margin_sampling)
        elif (method == 'cosine similarity'):
            features_normalized = F.normalize(features, p=2, dim=1)
            cosine_similarity = calculate_cosine_similarity(features_normalized)
            scores = -np.array(cosine_similarity)
        elif (method == 'l2 norm'):
            features_normalized = F.normalize(features, p=2, dim=1)
            l2_norm = calculate_l2_norm(features_normalized)
            scores = -np.array(l2_norm)
        elif (method == 'kl divergence'):
            feature_distances = pairwise_distances(features.cpu().detach().numpy(), metric='cosine')
            scores = calculate_kl_divergence(outputs, feature_distances)

        top_indices = np.argsort(scores)[-200:]
        new_samples = np.array(unlabeled_set)[top_indices].tolist()

        labeled_set.extend(new_samples)
        unlabeled_set = list(set(unlabeled_set) - set(new_samples))
# Out:
# method: least confidence     iteration: 1     accuracy: 90.35%
# method: least confidence     iteration: 2     accuracy: 92.00%
# method: least confidence     iteration: 3     accuracy: 94.63%
# method: prediction entropy     iteration: 1     accuracy: 89.19%
# method: prediction entropy     iteration: 2     accuracy: 95.35%
# method: prediction entropy     iteration: 3     accuracy: 95.46%
# method: margin sampling     iteration: 1     accuracy: 95.50%
# method: margin sampling     iteration: 2     accuracy: 95.58%
# method: margin sampling     iteration: 3     accuracy: 95.60%
# method: cosine similarity     iteration: 1     accuracy: 95.68%
# method: cosine similarity     iteration: 2     accuracy: 94.87%
# method: cosine similarity     iteration: 3     accuracy: 94.78%
# method: l2 norm     iteration: 1     accuracy: 95.10%
# method: l2 norm     iteration: 2     accuracy: 95.11%
# method: l2 norm     iteration: 3     accuracy: 94.01%
# method: kl divergence     iteration: 1     accuracy: 94.34%
# method: kl divergence     iteration: 2     accuracy: 94.34%
# method: kl divergence     iteration: 3     accuracy: 93.97%
